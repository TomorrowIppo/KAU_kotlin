// %% [markdown]
// # 📚Kotlin 중간고사 대비 단답식 문제집
//
// ## Chapter 1: 개요
//
// 1. 데이터와 함수를 병합하여 '객체' 단위로 프로그램을 나누고 이들의 상호작용을 서술하는 프로그래밍 방식을 무엇이라고 하는가?
//
// 2. 부모 클래스의 특징을 자식 클래스가 물려받는 객체지향 프로그래밍의 특징은 무엇인가?
//
// 3. 같은 이름의 메소드가 인자의 형태나 개수에 따라 다른 동작을 수행하는 다형성의 한 종류는 무엇인가?
//
// 4. 변수 선언 시 타입을 명시하지 않아도 컴파일러가 타입을 유추해 주는 Kotlin의 특징은 무엇인가?
//
//
// ## Chapter 2: 기초 문법 및 기본 타입
//
// 5. 한 번 초기화하면 값을 변경할 수 없는 읽기 전용 변수를 선언할 때 사용하는 키워드는 무엇인가?
//
// 6. readLine() 함수가 반환할 수 있는 null 값의 가능성을 무시하고, null이 아님을 프로그래머가 단언할 때 사용하는 연산자는 무엇인가?
//
// 7. 초기값 없이 변수를 선언할 때, 컴파일 오류를 피하기 위해 반드시 명시해야 하는 것은 무엇인가?
//
// 8. val n: Short = 100000 코드에서 발생하는 오류는 무엇인가?
//
// 9. Float 타입의 리터럴을 선언할 때 숫자 뒤에 붙이는 문자는 무엇인가?
//
// 10. ||, &&와 달리 양쪽 피연산자를 무조건 평가하는 논리 연산자는 무엇인가? (e.g., or, and)
//
// 11. s[1] = 'i' 와 같이 문자열의 특정 문자를 변경하려 할 때, Kotlin에서는 문자열이 OOOO 속성을 가지기 때문에 컴파일 오류가 발생한다. OOOO은 무엇인가?
//
// 12. 두 배열 a, b의 내용이 동일한지 비교하기 위해 사용해야 하는 함수는 무엇인가?
//
// 13. var a = arrayOf(1, 2, 3) 선언 후 a = arrayOf("one", "two")를 실행하면 어떤 오류가 발생하는가?
//
// 14. 배열의 대입(val b = a)은 실제 데이터의 복사가 아닌 OOO의 복사가 일어난다. OOO은 무엇인가?
//
//
// ## Chapter 3: 제어 흐름, 함수, 패키지
//
// 15. 반환값이 없는 함수의 반환 타입으로, 생략 가능한 이 타입의 이름은 무엇인가?
//
// 16. fun foo(bar: Int) { bar += 1 } 코드에서 bar 파라미터는 OOO 변수 특성을 가져 컴파일 오류가 발생한다. OOO은 무엇인가?
//
// 17. 함수 호출 시 mul(s = "a", n = 3)와 같이 파라미터의 이름을 명시하여 인자를 전달하는 방식을 무엇이라고 하는가?
//
// 18. 같은 파일 안에서만 호출 가능한 함수를 선언할 때 사용하는 가시성 제한자는 무엇인가?
//
// 19. import foo.readInt as fooRead와 같이 다른 패키지의 함수를 새로운 이름으로 가져올 때 사용하는 키워드는 무엇인가?
//
// 20. if-else문이나 when문이 값을 반환할 수 있어, 변수에 그 결과를 직접 대입할 수 있는 특징을 무엇이라고 하는가?
//
// 21. for (i in 0..9)와 달리 9를 포함하지 않고 0부터 8까지만 반복하는 범위를 만들 때 .. 대신 사용하는 키워드는 무엇인가?
//
// 22. 중첩된 반복문에서 안쪽이 아닌 바깥쪽 루프를 continue 하려고 할 때, 바깥쪽 루프 앞에 붙여주는 것을 무엇이라고 하는가?
//
// 23. try-catch 구문에서 예외 발생 여부와 관계없이 항상 실행되는 코드 블록을 정의하는 키워드는 무엇인가?
//
//
// ## Chapter 4: 클래스, 객체, Null Safety, 프로퍼티
//
// 24. 클래스 헤더에 선언하며, 클래스당 하나만 가질 수 있는 생성자는 무엇인가?
//
// 25. 주 생성자의 일부로, 객체 생성 시 실행되는 초기화 로직을 담는 코드 블록의 이름은 무엇인가?
//
// 26. 부 생성자에서 다른 생성자를 호출할 때 사용하는 키워드는 무엇인가?
//
// 27. 클래스 안에 inner 키워드 없이 선언된 클래스로, 외부 클래스의 인스턴스에 대한 참조가 없는 클래스는 무엇인가?
//
// 28. var s: String = null 코드에서 String 타입은 기본적으로 null을 허용하지 않으므로 발생하는 오류는 무엇인가?
//
// 29. readLine()!! 실행 시 사용자가 아무것도 입력하지 않고 EOF를 입력하면 어떤 런타임 예외(Exception)가 발생하는가?
//
// 30. if (s != null)과 같이 널 검사를 마치면, 해당 코드 블록 안에서 s가 자동으로 non-null 타입으로 취급되는 기능을 무엇이라고 하는가?
//
// 31. lateinit var text: String으로 선언된 프로퍼티를 초기화하기 전에 접근하면 어떤 런타임 예외가 발생하는가?
//
// 32. val 프로퍼티에 사용하며, 해당 프로퍼티에 처음 접근할 때 단 한번만 초기화 코드가 실행되도록 하는 지연 초기화 방식은 무엇인가?
//
// 33. 커스텀 get/set 내부에서 프로퍼티의 값을 저장하는 실제 메모리 공간에 접근하기 위해 사용하는 특수한 식별자는 무엇인가?
//
// 34. object 키워드로 선언하여 앱 전체에서 단 하나의 인스턴스만 존재하도록 보장하는 객체를 무엇이라고 하는가?
//
// 35. 클래스 내부에 companion object로 선언하여, 클래스의 모든 인스턴스가 공유하며 클래스 이름을 통해 직접 접근할 수 있는 객체는 무엇인가?
//
//
// ## Chapter 5: 함수형 프로그래밍, 확장, 영역 함수
//
// 36. 함수를 파라미터로 받거나 함수를 반환하는 함수를 무엇이라고 하는가?
//
// 37. 이름이 없는 함수로, { 파라미터 -> 본문 } 형태로 작성되는 함수 리터럴은 무엇인가?
//
// 38. fun add(...)와 같이 이미 존재하는 함수를 고차 함수의 인자로 넘길 때, 함수 자체를 참조하기 위해 사용하는 연산자는 무엇인가? (e.g., ::add)
//
// 39. 기존 클래스의 코드를 수정하지 않고 새로운 멤버 함수를 추가하는 기능을 무엇이라고 하는가?
//
// 40. 확장 프로퍼티는 값을 저장할 수 있는 OOOOO 필드를 가질 수 없기 때문에 반드시 get()을 명시적으로 정의해야 한다. OOOOO은 무엇인가?
//
// 41. Any 클래스처럼 OOO 객체가 없는 클래스는 동반 확장을 할 수 없다. OOO은 무엇인가?
//
// 42. ?. 연산자와 함께 사용하여, null이 아닌 경우에만 람다 블록을 실행하고 람다의 결과를 반환하는 영역 함수는 무엇인가?
//
// 43. 객체 초기화에 주로 사용되며, 람다 블록 실행 후 객체 자신(this)을 반환하는 영역 함수는 무엇인가?
